# %% [markdown]
# ## Imports and Functions

# %% [markdown]
# #### The code in the file ML.py is modified from material for Rayid Ghani's Spring 2018 ML for Public Policy course.

# %%
from data_functions import *
from ML_continuous import *

import warnings
warnings.filterwarnings('ignore')

import statsmodels.api as sm
import statsmodels.formula.api as smf

import random

# %%
def temporal_train_test_data_split(df, features, filter_var, outcome_var):
    start_date = 1992
    training_end_date = 2014
    testing_end_date = 2018

    y_df = df[[filter_var, outcome_var]]

    x_train_filter_by_date = filter_df_by_date_range(df, filter_var, training_end_date, testing_end_date)
    x_test_filter_by_date = filter_df_by_date_range(df, filter_var, start_date, training_end_date)

    y_train_filter_by_date = filter_df_by_date_range(y_df, filter_var, training_end_date, testing_end_date)
    y_test_filter_by_date = filter_df_by_date_range(y_df, filter_var, start_date, training_end_date)

    x_train = x_train_filter_by_date[features]
    x_test = x_test_filter_by_date[features]

    y_train = y_train_filter_by_date[outcome_var]
    y_test = y_test_filter_by_date[outcome_var]

    return x_test, x_train, y_test, y_train

# %% [markdown]
# ### Open and reformat data

# %%
data = read('texas_info.xlsx')
data.columns
# Out:
# Index(['election_year', 'candidate_name', 'vote_share', 'president',
#        'governor', 'senate', 'pres_elec_year', 'current_presidents_dem',
#        'unemployment', 'turnout', 'candidate_white', 'candidate_hispanic',
#        'candidate_male'],
#       dtype='object')

# %%
data
# Out:
#     election_year         candidate_name  vote_share  president  governor  \
# 0            2018            Lupe Valdez      0.4234          0         1
# 1            2018          Beto O'Rourke      0.4830          0         0
# 2            2016        Hillary Clinton      0.4324          1         0
# 3            2014            Wendy Davis      0.3890          0         1
# 4            2012           Barack Obama      0.4138          1         0
# 5            2012            Paul Sadler      0.4062          0         0
# 6            2010             Bill White      0.4230          0         1
# 7            2008            Barack Obma      0.4366          1         0
# 8            2006             Chris Bell      0.2979          0         1
# 9            2006  Barbara Ann Radnofsky      0.3605          0         0
# 10           2004             John Kerry      0.3822          1         0
# 11           2002           Tony Sanchez      0.3996          0         1
# 12           2000                Al Gore      0.3798          1         0
# 13           2000             Gene Kelly      0.3240          0         0
# 14           1998             Gary Mauro      0.3120          0         1
# 15           1996           Bill Clinton      0.4383          1         0
# 16           1994           Ann Richards      0.4590          0         1
# 17           1994       Richard W Fisher      0.3850          0         0
# 18           1992           Bill Clinton      0.3708          1         0
#
#     senate  pres_elec_year  current_presidents_dem  unemployment  turnout  \
# 0        0               0                       0           4.0   0.5300
# 1        1               0                       0           4.0   0.5300
# 2        0               1                       1           4.6   0.4645
# 3        0               0                       1           5.1   0.2499
# 4        0               1                       1           6.7   0.4373
# 5        1               1                       1           6.7   0.4373
# 6        0               0                       1           8.1   0.2700
# 7        0               1                       0           4.8   0.4555
# 8        0               0                       0           4.9   0.2644
# 9        1               0                       0           4.9   0.2644
# 10       0               1                       0           5.9   0.4611
# 11       0               0                       0           6.4   0.2935
# 12       0               1                       1           4.3   0.4425
# 13       1               1                       1           4.3   0.4425
# 14       0               0                       1           4.9   0.2653
# 15       0               1                       1           5.7   0.5324
# 16       0               0                       1           6.5   0.3362
# 17       1               0                       1           6.5   0.3362
# 18       0               1                       0           7.6   0.4764
#
#     candidate_white  candidate_hispanic  candidate_male
# 0                 0                   1               0
# 1                 1                   0               1
# 2                 1                   0               0
# 3                 1                   0               0
# 4                 0                   0               1
# 5                 1                   0               1
# 6                 1                   0               1
# 7                 1                   0               1
# 8                 1                   0               1
# 9                 1                   0               0
# 10                1                   0               1
# 11                1                   0               1
# 12                1                   0               1
# 13                1                   0               1
# 14                1                   0               1
# 15                1                   0               1
# 16                1                   0               0
# 17                1                   0               1
# 18                1                   0               1

# %% [markdown]
# #### Add columns that could be useful.

# %%
df = pd.concat([data, pd.get_dummies(data['election_year'])], axis=1)

# %%
df.columns = [ 'election_year','candidate_name','vote_share', 'president','governor','senate','pres_elec_year', 
              'current_presidents_dem','unemployment',  'turnout','candidate_white',     'candidate_hispanic',
               'candidate_male','1992','1994',                     '1996',
                           '1998',                     '2000',
                           '2002',                     '2004',
                           '2006',                     '2008',
                           '2010',                     '2012',
                           '2014',                     '2016',
                           '2018']

# %%
all_feats = ['pres_elec_year', 'current_presidents_dem',
                 'unemployment',                'turnout',
              'candidate_white',     'candidate_hispanic',
               'candidate_male']

# %% [markdown]
# ### Models

# %% [markdown]
# #### Model with all factors

# %%
offices = ['president', 'governor','senate',]
    
build_model = 'vote_share ~ ' + 'Q("' + str(random.choice(offices)) + '")' + ' + '

for f in all_feats:
    build_model = build_model + 'Q("' + str(f) + '")' + ' + '
    
build_model = build_model + "C(election_year)"

# %%
trial = smf.ols(build_model, data=df).fit()
print(trial.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             vote_share   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.342
# Method:                 Least Squares   F-statistic:                     1.551
# Date:                Tue, 13 Nov 2018   Prob (F-statistic):              0.567
# Time:                        14:55:12   Log-Likelihood:                 62.431
# No. Observations:                  19   AIC:                            -88.86
# Df Residuals:                       1   BIC:                            -71.86
# Df Model:                          17
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.1957      0.037      5.233      0.120      -0.279       0.671
# C(election_year)[T.1994]       -0.0033      0.030     -0.109      0.931      -0.382       0.376
# C(election_year)[T.1996]        0.0615      0.037      1.643      0.348      -0.414       0.537
# C(election_year)[T.1998]       -0.0302      0.043     -0.706      0.609      -0.573       0.513
# C(election_year)[T.2000]        0.0232      0.032      0.735      0.596      -0.378       0.425
# C(election_year)[T.2002]        0.0660      0.045      1.452      0.384      -0.511       0.643
# C(election_year)[T.2004]        0.0603      0.049      1.234      0.434      -0.560       0.681
# C(election_year)[T.2006]        0.0090      0.030      0.297      0.816      -0.375       0.393
# C(election_year)[T.2008]        0.1459      0.045      3.222      0.192      -0.429       0.721
# C(election_year)[T.2010]       -0.0087      0.034     -0.254      0.842      -0.445       0.428
# C(election_year)[T.2012]        0.0113      0.041      0.272      0.831      -0.516       0.538
# C(election_year)[T.2014]       -0.0255      0.045     -0.563      0.674      -0.601       0.550
# C(election_year)[T.2016]        0.0248      0.043      0.577      0.667      -0.522       0.572
# C(election_year)[T.2018]        0.1977      0.039      5.127      0.123      -0.292       0.688
# Q("governor")                   0.0057      0.039      0.144      0.909      -0.496       0.507
# Q("pres_elec_year")            -0.0092      0.030     -0.312      0.807      -0.385       0.366
# Q("current_presidents_dem")     0.0532      0.025      2.156      0.277      -0.260       0.367
# Q("unemployment")               0.0278      0.009      3.011      0.204      -0.090       0.145
# Q("turnout")                    0.1022      0.017      5.917      0.107      -0.117       0.322
# Q("candidate_white")           -0.0076      0.056     -0.136      0.914      -0.717       0.701
# Q("candidate_hispanic")        -0.1412      0.097     -1.461      0.382      -1.369       1.087
# Q("candidate_male")            -0.0683      0.039     -1.731      0.333      -0.570       0.433
# ==============================================================================
# Omnibus:                       13.019   Durbin-Watson:                   3.000
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               33.448
# Skew:                          -0.000   Prob(JB):                     5.46e-08
# Kurtosis:                       9.500   Cond. No.                     3.07e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The smallest eigenvalue is 7.2e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# #### Testing 4 factor models

# %%
best_name = ''
best_model = ''
best_rsquared = 0

for i in range(5):
    offices = ['president', 'governor','senate',]
    
    group_of_items = set(all_feats)             
    num_to_select = 4                          
    feats = random.sample(group_of_items, num_to_select)
    
    build_model = 'vote_share ~ ' + 'Q("' + str(random.choice(offices)) + '")' + ' + '
    for f in feats:
        build_model = build_model + 'Q("' + str(f) + '")' + ' + '
    build_model = build_model + "C(election_year)"
    
    trial = smf.ols(build_model, data=df).fit()
    if trial.rsquared > best_rsquared:
        best_model = trial
        best_name = build_model
        best_rsquared = trial.rsquared_adj

# %%
best_name
# Out:
# 'vote_share ~ Q("president") + Q("turnout") + Q("candidate_male") + Q("candidate_hispanic") + Q("unemployment") + C(election_year)'

# %%
print(best_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             vote_share   R-squared:                       0.986
# Model:                            OLS   Adj. R-squared:                  0.870
# Method:                 Least Squares   F-statistic:                     8.556
# Date:                Tue, 13 Nov 2018   Prob (F-statistic):              0.110
# Time:                        14:57:52   Log-Likelihood:                 71.281
# No. Observations:                  19   AIC:                            -108.6
# Df Residuals:                       2   BIC:                            -92.51
# Df Model:                          16
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.2583      0.021     12.252      0.007       0.168       0.349
# C(election_year)[T.1994]     0.0752      0.023      3.325      0.080      -0.022       0.173
# C(election_year)[T.1996]     0.0928      0.020      4.633      0.044       0.007       0.179
# C(election_year)[T.1998]     0.0287      0.020      1.437      0.287      -0.057       0.115
# C(election_year)[T.2000]     0.0498      0.014      3.667      0.067      -0.009       0.108
# C(election_year)[T.2002]     0.0914      0.024      3.751      0.064      -0.013       0.196
# C(election_year)[T.2004]     0.0385      0.021      1.870      0.202      -0.050       0.127
# C(election_year)[T.2006]     0.0118      0.016      0.762      0.526      -0.055       0.079
# C(election_year)[T.2008]     0.1101      0.020      5.606      0.030       0.026       0.195
# C(election_year)[T.2010]     0.0904      0.031      2.950      0.098      -0.041       0.222
# C(election_year)[T.2012]     0.0715      0.019      3.722      0.065      -0.011       0.154
# C(election_year)[T.2014]     0.0354      0.023      1.540      0.263      -0.063       0.134
# C(election_year)[T.2016]     0.0401      0.022      1.805      0.213      -0.055       0.136
# C(election_year)[T.2018]     0.1954      0.019     10.336      0.009       0.114       0.277
# Q("president")               0.0317      0.018      1.810      0.212      -0.044       0.107
# Q("turnout")                 0.0684      0.012      5.653      0.030       0.016       0.120
# Q("candidate_male")         -0.0683      0.018     -3.900      0.060      -0.144       0.007
# Q("candidate_hispanic")     -0.1279      0.030     -4.217      0.052      -0.258       0.003
# Q("unemployment")            0.0153      0.006      2.692      0.115      -0.009       0.040
# ==============================================================================
# Omnibus:                        3.040   Durbin-Watson:                   3.000
# Prob(Omnibus):                  0.219   Jarque-Bera (JB):                1.284
# Skew:                           0.000   Prob(JB):                        0.526
# Kurtosis:                       4.273   Cond. No.                     5.33e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.3e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
