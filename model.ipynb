# %% [markdown]
# ## Imports and Functions

# %% [markdown]
# #### The code in the file ML.py is modified from material for Rayid Ghani's Spring 2018 ML for Public Policy course.

# %%
from data_functions import *
from ML_continuous import *

import warnings
warnings.filterwarnings('ignore')

import statsmodels.api as sm
import statsmodels.formula.api as smf

import random

# %%
def temporal_train_test_data_split(df, features, filter_var, outcome_var):
    start_date = 1992
    training_end_date = 2014
    testing_end_date = 2018

    y_df = df[[filter_var, outcome_var]]

    x_train_filter_by_date = filter_df_by_date_range(df, filter_var, training_end_date, testing_end_date)
    x_test_filter_by_date = filter_df_by_date_range(df, filter_var, start_date, training_end_date)

    y_train_filter_by_date = filter_df_by_date_range(y_df, filter_var, training_end_date, testing_end_date)
    y_test_filter_by_date = filter_df_by_date_range(y_df, filter_var, start_date, training_end_date)

    x_train = x_train_filter_by_date[features]
    x_test = x_test_filter_by_date[features]

    y_train = y_train_filter_by_date[outcome_var]
    y_test = y_test_filter_by_date[outcome_var]

    return x_test, x_train, y_test, y_train

# %% [markdown]
# ### Open and reformat data

# %%
data = read('texas_info.xlsx')
data.columns
# Out:
# Index(['election_year', 'candidate_name', 'vote_share', 'president',
#        'governor', 'senate', 'pres_elec_year', 'current_presidents_dem',
#        'unemployment', 'turnout', 'candidate_white', 'candidate_hispanic',
#        'candidate_male'],
#       dtype='object')

# %%
data.iloc[11]['candidate_hispanic'] = 1
# make tony sanchez hispanic

# %%
data
# Out:
#     election_year         candidate_name  vote_share  president  governor  \
# 0            2018            Lupe Valdez      0.4234          0         1
# 1            2018          Beto O'Rourke      0.4830          0         0
# 2            2016        Hillary Clinton      0.4324          1         0
# 3            2014            Wendy Davis      0.3890          0         1
# 4            2012           Barack Obama      0.4138          1         0
# 5            2012            Paul Sadler      0.4062          0         0
# 6            2010             Bill White      0.4230          0         1
# 7            2008            Barack Obma      0.4366          1         0
# 8            2006             Chris Bell      0.2979          0         1
# 9            2006  Barbara Ann Radnofsky      0.3605          0         0
# 10           2004             John Kerry      0.3822          1         0
# 11           2002           Tony Sanchez      0.3996          0         1
# 12           2000                Al Gore      0.3798          1         0
# 13           2000             Gene Kelly      0.3240          0         0
# 14           1998             Gary Mauro      0.3120          0         1
# 15           1996           Bill Clinton      0.4383          1         0
# 16           1994           Ann Richards      0.4590          0         1
# 17           1994       Richard W Fisher      0.3850          0         0
# 18           1992           Bill Clinton      0.3708          1         0
#
#     senate  pres_elec_year  current_presidents_dem  unemployment  turnout  \
# 0        0               0                       0           4.0   0.5300
# 1        1               0                       0           4.0   0.5300
# 2        0               1                       1           4.6   0.4645
# 3        0               0                       1           5.1   0.2499
# 4        0               1                       1           6.7   0.4373
# 5        1               1                       1           6.7   0.4373
# 6        0               0                       1           8.1   0.2700
# 7        0               1                       0           4.8   0.4555
# 8        0               0                       0           4.9   0.2644
# 9        1               0                       0           4.9   0.2644
# 10       0               1                       0           5.9   0.4611
# 11       0               0                       0           6.4   0.2935
# 12       0               1                       1           4.3   0.4425
# 13       1               1                       1           4.3   0.4425
# 14       0               0                       1           4.9   0.2653
# 15       0               1                       1           5.7   0.5324
# 16       0               0                       1           6.5   0.3362
# 17       1               0                       1           6.5   0.3362
# 18       0               1                       0           7.6   0.4764
#
#     candidate_white  candidate_hispanic  candidate_male
# 0                 0                   1               0
# 1                 1                   0               1
# 2                 1                   0               0
# 3                 1                   0               0
# 4                 0                   0               1
# 5                 1                   0               1
# 6                 1                   0               1
# 7                 1                   0               1
# 8                 1                   0               1
# 9                 1                   0               0
# 10                1                   0               1
# 11                1                   0               1
# 12                1                   0               1
# 13                1                   0               1
# 14                1                   0               1
# 15                1                   0               1
# 16                1                   0               0
# 17                1                   0               1
# 18                1                   0               1

# %% [markdown]
# #### Add columns that could be useful.

# %%
df = pd.concat([data, pd.get_dummies(data['election_year'])], axis=1)

# %%
df.columns = [ 'election_year','candidate_name','vote_share', 'president','governor','senate','pres_elec_year', 
              'current_presidents_dem','unemployment',  'turnout','candidate_white',     'candidate_hispanic',
               'candidate_male','1992','1994',                     '1996',
                           '1998',                     '2000',
                           '2002',                     '2004',
                           '2006',                     '2008',
                           '2010',                     '2012',
                           '2014',                     '2016',
                           '2018']

# %%
all_feats = ['pres_elec_year', 'current_presidents_dem',
                 'unemployment',                'turnout',
              'candidate_white',     'candidate_hispanic',
               'candidate_male']

# %% [markdown]
# ### Models

# %% [markdown]
# #### Model with all factors

# %%
offices = ['president', 'governor','senate',]
    
build_model = 'vote_share ~ ' + 'Q("' + str(random.choice(offices)) + '")' + ' + '

for f in all_feats:
    build_model = build_model + 'Q("' + str(f) + '")' + ' + '
    
build_model = build_model + "C(election_year)"

# %%
build_model
# Out:
# 'vote_share ~ Q("president") + Q("current_presidents_dem") + Q("candidate_hispanic") + Q("candidate_male") + Q("candidate_white") + C(election_year)'

# %%
trial = smf.ols(build_model, data=df).fit()
print(trial.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             vote_share   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.646
# Method:                 Least Squares   F-statistic:                     2.936
# Date:                Tue, 13 Nov 2018   Prob (F-statistic):              0.433
# Time:                        15:35:45   Log-Likelihood:                 68.330
# No. Observations:                  19   AIC:                            -100.7
# Df Residuals:                       1   BIC:                            -83.66
# Df Model:                          17
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.1938      0.027      7.127      0.089      -0.152       0.539
# C(election_year)[T.1994]        0.0018      0.022      0.081      0.949      -0.274       0.277
# C(election_year)[T.1996]        0.0561      0.028      2.020      0.293      -0.297       0.409
# C(election_year)[T.1998]       -0.0367      0.031     -1.181      0.447      -0.432       0.358
# C(election_year)[T.2000]        0.0263      0.023      1.123      0.463      -0.271       0.324
# C(election_year)[T.2002]        0.0640      0.031      2.076      0.286      -0.327       0.455
# C(election_year)[T.2004]        0.0569      0.036      1.583      0.359      -0.400       0.513
# C(election_year)[T.2006]        0.0123      0.022      0.552      0.679      -0.271       0.296
# C(election_year)[T.2008]        0.1402      0.034      4.183      0.149      -0.286       0.566
# C(election_year)[T.2010]       -0.0088      0.025     -0.353      0.784      -0.325       0.308
# C(election_year)[T.2012]        0.0304      0.037      0.827      0.560      -0.436       0.497
# C(election_year)[T.2014]       -0.0316      0.033     -0.959      0.513      -0.450       0.387
# C(election_year)[T.2016]        0.0173      0.032      0.532      0.689      -0.396       0.430
# C(election_year)[T.2018]        0.2074      0.029      7.079      0.089      -0.165       0.580
# Q("senate")                    -0.0224      0.024     -0.948      0.517      -0.322       0.278
# Q("pres_elec_year")            -0.0146      0.014     -1.042      0.487      -0.193       0.163
# Q("current_presidents_dem")     0.0547      0.017      3.243      0.190      -0.160       0.269
# Q("unemployment")               0.0258      0.007      3.703      0.168      -0.063       0.114
# Q("turnout")                    0.1027      0.012      8.801      0.072      -0.046       0.251
# Q("candidate_white")            0.0148      0.047      0.313      0.807      -0.585       0.615
# Q("candidate_hispanic")        -0.1355      0.065     -2.095      0.284      -0.957       0.686
# Q("candidate_male")            -0.0683      0.029     -2.361      0.255      -0.436       0.299
# ==============================================================================
# Omnibus:                        4.144   Durbin-Watson:                   3.000
# Prob(Omnibus):                  0.126   Jarque-Bera (JB):                2.424
# Skew:                           0.000   Prob(JB):                        0.298
# Kurtosis:                       4.750   Cond. No.                     3.52e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The smallest eigenvalue is 5.45e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# #### Testing 4 factor models

# %%
best_name = ''
best_model = ''
best_rsquared = 0

for i in range(5):
    offices = ['president', 'governor','senate',]
    
    group_of_items = set(all_feats)             
    num_to_select = 4                          
    feats = random.sample(group_of_items, num_to_select)
    
    build_model = 'vote_share ~ ' + 'Q("' + str(random.choice(offices)) + '")' + ' + '
    for f in feats:
        build_model = build_model + 'Q("' + str(f) + '")' + ' + '
    build_model = build_model + "C(election_year)"
    
    trial = smf.ols(build_model, data=df).fit()
    if trial.rsquared > best_rsquared:
        best_model = trial
        best_name = build_model
        best_rsquared = trial.rsquared_adj

# %%
best_name
# Out:
# 'vote_share ~ Q("president") + Q("current_presidents_dem") + Q("candidate_hispanic") + Q("candidate_male") + Q("candidate_white") + C(election_year)'

# %%
print(best_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             vote_share   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.986
# Method:                 Least Squares   F-statistic:                     77.06
# Date:                Tue, 13 Nov 2018   Prob (F-statistic):             0.0894
# Time:                        15:35:45   Log-Likelihood:                 99.191
# No. Observations:                  19   AIC:                            -162.4
# Df Residuals:                       1   BIC:                            -145.4
# Df Model:                          17
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.3351      0.020     16.971      0.037       0.084       0.586
# C(election_year)[T.1994]        0.0346      0.005      6.619      0.095      -0.032       0.101
# C(election_year)[T.1996]        0.0292      0.007      3.931      0.159      -0.065       0.124
# C(election_year)[T.1998]       -0.0413      0.006     -6.462      0.098      -0.122       0.040
# C(election_year)[T.2000]       -0.0293      0.004     -6.691      0.094      -0.085       0.026
# C(election_year)[T.2002]        0.0846      0.011      7.421      0.085      -0.060       0.229
# C(election_year)[T.2004]        0.0114      0.008      1.414      0.392      -0.091       0.114
# C(election_year)[T.2006]       -0.0200      0.011     -1.807      0.322      -0.160       0.120
# C(election_year)[T.2008]        0.0658      0.008      8.163      0.078      -0.037       0.168
# C(election_year)[T.2010]        0.0697      0.006     10.913      0.058      -0.011       0.151
# C(election_year)[T.2012]        0.0529      0.006      8.283      0.076      -0.028       0.134
# C(election_year)[T.2014]       -0.0326      0.007     -4.383      0.143      -0.127       0.062
# C(election_year)[T.2016]       -0.0450      0.008     -5.388      0.117      -0.151       0.061
# C(election_year)[T.2018]        0.1680      0.011     14.737      0.043       0.023       0.313
# Q("president")                  0.0558      0.008      6.922      0.091      -0.047       0.158
# Q("current_presidents_dem")     0.0383      0.007      5.150      0.122      -0.056       0.133
# Q("candidate_hispanic")        -0.0797      0.015     -5.285      0.119      -0.271       0.112
# Q("candidate_male")            -0.0683      0.006    -11.982      0.053      -0.141       0.004
# Q("candidate_white")            0.0482      0.011      4.228      0.148      -0.097       0.193
# ==============================================================================
# Omnibus:                        4.144   Durbin-Watson:                   3.000
# Prob(Omnibus):                  0.126   Jarque-Bera (JB):                2.424
# Skew:                          -0.000   Prob(JB):                        0.298
# Kurtosis:                       4.750   Cond. No.                     1.86e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.66e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
pd.read_excel('hstpov9.xls')
# Out:
#    Table with row headers in column A and column headers in rows 4 to 6.  \
# 0   Table 9. Poverty of People, by Region: 1959 to...
# 1   NOTE: Numbers in thousands. People as of March...
# 2                                                Year
# 3                                                 NaN
# 4                                                 NaN
# 5                                                2017
# 6                                                2016
# 7                                                2015
# 8                                                2014
# 9                                           2013 (19)
# 10                                          2013 (18)
# 11                                               2012
# 12                                               2011
# 13                                          2010 (17)
# 14                                               2009
# 15                                               2008
# 16                                               2007
# 17                                               2006
# 18                                               2005
# 19                                          2004 (14)
# 20                                               2003
# 21                                               2002
# 22                                               2001
# 23                                          2000 (12)
# 24                                          1999 (11)
# 25                                               1998
# 26                                               1997
# 27                                               1996
# 28                                               1995
# 29                                               1994
# 30                                          1993 (10)
# 31                                          1992 (9 )
# 32                                          1991 (8 )
# 33                                               1990
# 34                                               1989
# 35                                               1988
# 36                                          1987 (7 )
# 37                                               1986
# 38                                               1985
# 39                                               1984
# 40                                          1983 (6 )
# 41                                               1982
# 42                                          1981 (5 )
# 43                                               1980
# 44                                          1979 (4 )
# 45                                               1978
# 46                                               1977
# 47                                               1976
# 48                                               1975
# 49                                          1974 (3 )
# 50                                               1973
# 51                                               1972
# 52                                          1971 (2 )
# 53                                               1970
# 54                                               1969
# 55                                               1960
# 56                                               1959
# 57  SOURCE: U.S. Bureau of the Census, Current Pop...
#
#    Unnamed: 1     Unnamed: 2 Unnamed: 3 Unnamed: 4     Unnamed: 5 Unnamed: 6  \
# 0         NaN            NaN        NaN        NaN            NaN        NaN
# 1         NaN            NaN        NaN        NaN            NaN        NaN
# 2       Total            NaN        NaN  Northeast            NaN        NaN
# 3       Total  Below poverty        NaN      Total  Below poverty        NaN
# 4         NaN         Number    Percent        NaN         Number    Percent
# 5      322549          39698       12.3      55972           6373       11.4
# 6      319911          40616       12.7      55470           5969       10.8
# 7      318454          43123       13.5      55779           6891       12.4
# 8      315804          46657       14.8      55725           7020       12.6
# 9      313096          46269       14.8      55529           7205         13
# 10     312965          45318       14.5      55478           7046       12.7
# 11     310648          46496         15      55050           7490       13.6
# 12     308456          46247         15      54977           7208       13.1
# 13     306130          46343       15.1      54710           7038       12.9
# 14     303820          43569       14.3      54571           6650       12.2
# 15     301041          39829       13.2      54123           6295       11.6
# 16     298699          37276       12.5      53952           6166       11.4
# 17     296450          36460       12.3      54072           6222       11.5
# 18     293135          36950       12.6      54010           6103       11.3
# 19     290617          37040       12.7      53906           6260       11.6
# 20     287699          35861       12.5      53608           6052       11.3
# 21     285317          34570       12.1      54023           5871       10.9
# 22     281475          32907       11.7      53193           5687       10.7
# 23     278944          31581       11.3      52961           5474       10.3
# 24     276208          32791       11.9      52862           5814         11
# 25     271059          34476       12.7      51742           6357       12.3
# 26     268480          35574       13.3      51202           6474       12.6
# 27     266218          36529       13.7      51455           6558       12.7
# 28     263733          36425       13.8      51429           6445       12.5
# 29     261616          38059       14.5      51185           6597       12.9
# 30     259278          39265       15.1      51474           6839       13.3
# 31     256549          38014       14.8      50808           6414       12.6
# 32     251192          35708       14.2      50789           6177       12.2
# 33     248644          33585       13.5      50799           5794       11.4
# 34     245992          31528       12.8      50520           5061         10
# 35     243530          31745         13      50272           5089       10.1
# 36     240982          32221       13.4      49654           5476         11
# 37     238554          32370       13.6      49572           5211       10.5
# 38     236594          33064         14      49413           5751       11.6
# 39     233816          33700       14.4      49374           6531       13.2
# 40     231700          35303       15.2      49132           6561       13.4
# 41     229412          34398         15      49054           6364         13
# 42     227157          31822         14      48944           5815       11.9
# 43     225027          29272         13      48533           5369       11.1
# 44     222903          26072       11.7      48414           5029       10.4
# 45     215656          24497       11.4      48576           5050       10.4
# 46     213867          24720       11.6      48823           4956       10.2
# 47     212303          24975       11.8      48508           4949       10.2
# 48     210864          25877       12.3      48154           4904       10.2
# 49     209362          23370       11.2      48182           4473        9.3
# 50     207621          22973       11.1      48829           4207        8.6
# 51     206004          24460       11.9      48853           4266        8.7
# 52     204554          25559       12.5      48584           4512        9.3
# 53     202183          25420       12.6       (NA)           (NA)       (NA)
# 54     199517          24147       12.1      47597           4108        8.6
# 55     179503          39851       22.2       (NA)           (NA)       (NA)
# 56     176557          39490       22.4       (NA)           (NA)       (NA)
# 57        NaN            NaN        NaN        NaN            NaN        NaN
#
#    Unnamed: 7     Unnamed: 8 Unnamed: 9 Unnamed: 10    Unnamed: 11  \
# 0         NaN            NaN        NaN         NaN            NaN
# 1         NaN            NaN        NaN         NaN            NaN
# 2     Midwest            NaN        NaN       South            NaN
# 3       Total  Below poverty        NaN       Total  Below poverty
# 4         NaN         Number    Percent         NaN         Number
# 5       67345           7647       11.4      122250          16609
# 6       66897           7809       11.7      121166          17028
# 7       67030           7849       11.7      119955          18305
# 8       67130           8714         13      118193          19531
# 9       66732           9269       13.9      116956          19040
# 10      66785           8590       12.9      116961          18870
# 11      66337           8851       13.3      115957          19106
# 12      66023           9221         14      114936          18380
# 13      66038           9216         14      113681          19123
# 14      65980           8768       13.3      112165          17609
# 15      65589           8120       12.4      110666          15862
# 16      65403           7237       11.1      109545          15501
# 17      65411           7324       11.2      107902          14882
# 18      64973           7419       11.4      106089          14854
# 19      64740           7545       11.7      104887          14817
# 20      64655           6932       10.7      103347          14548
# 21      64472           6616       10.3      101575          14019
# 22      63676           5966        9.4      100421          13515
# 23      63509           5916        9.3       99242          12705
# 24      63718           6250        9.8       96898          12744
# 25      63155           6501       10.3       94640          12992
# 26      62498           6493       10.4       94235          13748
# 27      61940           6654       10.7       93123          14098
# 28      61773           6785         11       92027          14458
# 29      61379           7965         13       91717          14729
# 30      61158           8172       13.4       89654          15375
# 31      60793           8060       13.3       88763          15198
# 32      60371           7989       13.2       85895          13783
# 33      59914           7458       12.4       85097          13456
# 34      59428           7043       11.9       84044          12943
# 35      59493           6804       11.4       83817          13530
# 36      59072           7499       12.7       82447          13287
# 37      58702           7641         13       81646          13106
# 38      58745           8191       13.9       80604          12921
# 39      58749           8303       14.1       79195          12792
# 40      58295           8536       14.6       78570          13484
# 41      58228           7772       13.3       77375          13967
# 42      58183           7142       12.3       76034          13256
# 43      58054           6592       11.4       75001          12363
# 44      57773           5594        9.7       70884          10627
# 45      57313           5192        9.1       69910          10255
# 46      56969           5589        9.8       69148          10249
# 47      57157           5657        9.9       68236          10354
# 48      56397           5459        9.7       68095          11059
# 49      56598           4990        8.8       66925          10761
# 50      56437           4864        8.6       65613          10061
# 51      56502           5258        9.3       64579          10928
# 52      56107           5764       10.3       63746          11182
# 53       (NA)           (NA)       (NA)       61890          11480
# 54      56286           5424        9.6       61825          11090
# 55       (NA)           (NA)       (NA)        (NA)           (NA)
# 56       (NA)           (NA)       (NA)       53941          19116
# 57        NaN            NaN        NaN         NaN            NaN
#
#    Unnamed: 12 Unnamed: 13    Unnamed: 14 Unnamed: 15
# 0          NaN         NaN            NaN         NaN
# 1          NaN         NaN            NaN         NaN
# 2          NaN        West            NaN         NaN
# 3          NaN       Total  Below poverty         NaN
# 4      Percent         NaN         Number     Percent
# 5         13.6       76982           9069        11.8
# 6         14.1       76377           9810        12.8
# 7         15.3       75690          10079        13.3
# 8         16.5       74756          11391        15.2
# 9         16.3       73879          10754        14.6
# 10        16.1       73742          10812        14.7
# 11        16.5       73303          11049        15.1
# 12          16       72520          11437        15.8
# 13        16.8       71701          10966        15.3
# 14        15.7       71103          10542        14.8
# 15        14.3       70663           9552        13.5
# 16        14.2       69799           8372          12
# 17        13.8       69065           8032        11.6
# 18          14       68063           8573        12.6
# 19        14.1       67083           8419        12.5
# 20        14.1       66089           8329        12.6
# 21        13.8       65248           8064        12.4
# 22        13.5       64185           7739        12.1
# 23        12.8       63232           7485        11.8
# 24        13.2       62729           7982        12.7
# 25        13.7       61522           8625          14
# 26        14.6       60545           8858        14.6
# 27        15.1       59700           9219        15.4
# 28        15.7       58503           8736        14.9
# 29        16.1       57335           8768        15.3
# 30        17.1       56992           8879        15.6
# 31        17.1       56186           8343        14.8
# 32          16       54136           7759        14.3
# 33        15.8       52835           6877          13
# 34        15.4       52000           6481        12.5
# 35        16.1       49948           6322        12.7
# 36        16.1       49717           6285        12.6
# 37        16.1       48634           6412        13.2
# 38          16       47832           6201          13
# 39        16.2       46498           6074        13.1
# 40        17.2       45616           6684        14.7
# 41        18.1       44754           6296        14.1
# 42        17.4       43997           5609        12.7
# 43        16.5       43439           4958        11.4
# 44          15       40777           4095          10
# 45        14.7       39858           4000          10
# 46        14.8       38927           3927        10.1
# 47        15.2       38402           4015        10.5
# 48        16.2       38218           4454        11.7
# 49        16.1       37638           4036        10.7
# 50        15.3       36742           3841        10.5
# 51        16.9       36070           4008        11.1
# 52        17.5       36116           4101        11.4
# 53        18.5        (NA)           (NA)        (NA)
# 54        17.9       33809           3525        10.4
# 55        (NA)        (NA)           (NA)        (NA)
# 56        35.4        (NA)           (NA)        (NA)
# 57         NaN         NaN            NaN         NaN
