# %% [markdown]
# ## Imports and Functions

# %% [markdown]
# #### The code in the file ML.py is modified from material for Rayid Ghani's Spring 2018 ML for Public Policy course.

# %%
from data_functions import *
from ML import *

import warnings
warnings.filterwarnings('ignore')

# %%
def temporal_train_test_data_split(df, features, filter_var, outcome_var):
    start_date = '2004'
    training_end_date = '2008'
    testing_end_date = '2010'

    y_df = df[[filter_var, outcome_var]]

    x_train_filter_by_date = filter_df_by_date_range(df, filter_var, training_end_date, testing_end_date)
    x_test_filter_by_date = filter_df_by_date_range(df, filter_var, start_date, training_end_date)

    y_train_filter_by_date = filter_df_by_date_range(y_df, filter_var, training_end_date, testing_end_date)
    y_test_filter_by_date = filter_df_by_date_range(y_df, filter_var, start_date, training_end_date)

    x_train = x_train_filter_by_date[features]
    x_test = x_test_filter_by_date[features]

    y_train = y_train_filter_by_date[outcome_var]
    y_test = y_test_filter_by_date[outcome_var]

    return x_test, x_train, y_test, y_train

# %%
def single_year(df, year):
    
    voting_cols = ['voted2004','voted2006', 'voted2008', 'voted2010']
    common = ['county', 'name', 'city', 'zip', 'address', 'phone', 'gender', 'age',
       'precinct', 'cong_dist', 'nc_senate', 'nc_house', 'idx', 'white',
       'black', 'hispanic', 'dem', 'rep']

    df['election_year'] = year
    col_name = "voted" + year
    voting_cols.remove(col_name)
    df = df[common + ['election_year'] + [col_name]]
    df.columns = common + ['election_year'] + ['voted']

    return df

# %% [markdown]
# ### Open and reformat data

# %%
data = read('voterfileNC.dta')
data = data.rename(index=str, columns={"id": "idx"})
data.columns
# Out:
# Index(['county', 'name', 'city', 'zip', 'address', 'phone', 'gender', 'age',
#        'precinct', 'cong_dist', 'nc_senate', 'nc_house', 'idx', 'white',
#        'black', 'hispanic', 'dem', 'rep', 'regyear', 'voted2004', 'voted2006',
#        'voted2008', 'voted2010'],
#       dtype='object')

# %% [markdown]
# ### Reshape the data to “long” format such that each row pertains to an individual in a given election year.

# %%
v04, v06, v08, v10 = data.copy(), data.copy(), data.copy(), data.copy()

# %%
v04_only = single_year(v04, '2004')
v06_only = single_year(v06, '2006')
v08_only = single_year(v08, '2008')
v10_only = single_year(v10, '2010')

# %%
frames = [v04_only, v06_only, v08_only, v10_only]
long = pd.concat(frames)

# %%
l = long.copy()
l.shape
# Out:
# (40000, 20)

# %% [markdown]
# ## Part 1: Predict likely voters

# %% [markdown]
# ### Briefly discuss relevant predictors in the voter file (voterfileNC.dta)

# %% [markdown]
# Factors that can be predictive of turnout include race (white, black), ethnicity (hispanic), gender, and age. Young people in particular generally have low turnout rates. Their address or location could be influential as well, but that would likely be due to and reflected in other factors.

# %% [markdown]
# #### Add columns that could be useful.

# %%
l['is_midterm'] = l.election_year.apply(lambda x: 1 if (int(x) % 4 == 0) else 1)
l['gender'] = l.gender.apply(lambda x: 1 if x == 'F' else 0)

# %%
l.head().style
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >county</th>
#         <th class="col_heading level0 col1" >name</th>
#         <th class="col_heading level0 col2" >city</th>
#         <th class="col_heading level0 col3" >zip</th>
#         <th class="col_heading level0 col4" >address</th>
#         <th class="col_heading level0 col5" >phone</th>
#         <th class="col_heading level0 col6" >gender</th>
#         <th class="col_heading level0 col7" >age</th>
#         <th class="col_heading level0 col8" >precinct</th>
#         <th class="col_heading level0 col9" >cong_dist</th>
#         <th class="col_heading level0 col10" >nc_senate</th>
#         <th class="col_heading level0 col11" >nc_house</th>
#         <th class="col_heading level0 col12" >idx</th>
#         <th class="col_heading level0 col13" >white</th>
#         <th class="col_heading level0 col14" >black</th>
#         <th class="col_heading level0 col15" >hispanic</th>
#         <th class="col_heading level0 col16" >dem</th>
#         <th class="col_heading level0 col17" >rep</th>
#         <th class="col_heading level0 col18" >election_year</th>
#         <th class="col_heading level0 col19" >voted</th>
#         <th class="col_heading level0 col20" >is_midterm</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row0_col0" class="data row0 col0" >COLUMBUS</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row0_col1" class="data row0 col1" >MICHELLE  MCPHERSON </td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row0_col2" class="data row0 col2" >CLARENDON</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row0_col3" class="data row0 col3" >28432</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row0_col4" class="data row0 col4" >2184  BEAVERDAM RD   </td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row0_col5" class="data row0 col5" >910 653 3698</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row0_col6" class="data row0 col6" >1</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row0_col7" class="data row0 col7" >43</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row0_col8" class="data row0 col8" >P24   </td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row0_col9" class="data row0 col9" >7</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row0_col10" class="data row0 col10" >13</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row0_col11" class="data row0 col11" >46</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row0_col12" class="data row0 col12" >BC48282</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row0_col13" class="data row0 col13" >1</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row0_col14" class="data row0 col14" >0</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row0_col15" class="data row0 col15" >0</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row0_col16" class="data row0 col16" >0</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row0_col17" class="data row0 col17" >0</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row0_col18" class="data row0 col18" >2004</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row0_col19" class="data row0 col19" >1</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row0_col20" class="data row0 col20" >1</td>
#     </tr>    <tr>
#         <th id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row1_col0" class="data row1 col0" >LENOIR</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row1_col1" class="data row1 col1" >JUSTIN MAURICE RHODES </td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row1_col2" class="data row1 col2" >KINSTON</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row1_col3" class="data row1 col3" >28504</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row1_col4" class="data row1 col4" >2204  TANGLEWOOD DR   </td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row1_col5" class="data row1 col5" >252 523 0324</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row1_col6" class="data row1 col6" >0</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row1_col7" class="data row1 col7" >22</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row1_col8" class="data row1 col8" >K9    </td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row1_col9" class="data row1 col9" >1</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row1_col10" class="data row1 col10" >5</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row1_col11" class="data row1 col11" >12</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row1_col12" class="data row1 col12" >CM55969</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row1_col13" class="data row1 col13" >0</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row1_col14" class="data row1 col14" >1</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row1_col15" class="data row1 col15" >0</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row1_col16" class="data row1 col16" >1</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row1_col17" class="data row1 col17" >0</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row1_col18" class="data row1 col18" >2004</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row1_col19" class="data row1 col19" >0</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row1_col20" class="data row1 col20" >1</td>
#     </tr>    <tr>
#         <th id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row2_col0" class="data row2 col0" >ROBESON</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row2_col1" class="data row2 col1" >LOTTIE BARTON BULLARD </td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row2_col2" class="data row2 col2" >MAXTON</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row2_col3" class="data row2 col3" >28364</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row2_col4" class="data row2 col4" >238  BARTON RD   </td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row2_col5" class="data row2 col5" >910 843 3619</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row2_col6" class="data row2 col6" >1</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row2_col7" class="data row2 col7" >65</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row2_col8" class="data row2 col8" >34    </td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row2_col9" class="data row2 col9" >7</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row2_col10" class="data row2 col10" >13</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row2_col11" class="data row2 col11" >47</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row2_col12" class="data row2 col12" >DR39304</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row2_col13" class="data row2 col13" >0</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row2_col14" class="data row2 col14" >0</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row2_col15" class="data row2 col15" >0</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row2_col16" class="data row2 col16" >1</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row2_col17" class="data row2 col17" >0</td>
#         <td id="T_e0b7dfc8_e5e4_11e8_8bb9_f0189800a658row2_col18" class="data row2 col18" >2004<

# %%
l.columns
# Out:
# Index(['county', 'name', 'city', 'zip', 'address', 'phone', 'gender', 'age',
#        'precinct', 'cong_dist', 'nc_senate', 'nc_house', 'idx', 'white',
#        'black', 'hispanic', 'dem', 'rep', 'election_year', 'voted',
#        'is_midterm'],
#       dtype='object')

# %% [markdown]
# #### I narrowed down the features so that I did not double count any of the characteristiscs like white vs. black or rep vs. dem.

# %%
rfeats = ['gender', 'white', 'hispanic', 'rep', 'is_midterm', 'age']

# %%
x_train, x_test, y_train, y_test  = temporal_train_test_data_split(l, rfeats , 'election_year', 'voted')

# %% [markdown]
# ### Models

# %%
results_df = run_simple_loop(x_train, x_test, y_train, y_test, 'small')
# Out:
# DT
# KNN
# LR

# %% [markdown]
# ### Test their predictive performance.

# %%
results_df = results_df[['model_type', 'clf', 'parameters', 'baseline_p', 'auc-roc', 'p_at_10', 'r_at_10', 'f1_at_10']]

# %%
results_df.to_pickle('results_df.pkl')
results_df = pd.read_pickle('results_df.pkl')

# %% [markdown]
# #### I decided to use the metric of precision at 10% to select voters to target. We are looking for 1000-2000 candidates out of 10,000 potential voters, so 10%. I also decided that being able to correctly identify a potential voter, precision, was more important than classifying all voters correctly. Knowing which models had the highest precision would be more helpful in making predictions for the future.  I looked at a total of 98 models: 36 decision trees, 36 K-nearest neighbors, and 10 logistic regressions.

# %%
dt_results = results_df[results_df.model_type == 'DT']
knn_results = results_df[results_df.model_type == 'KNN']
lr_results = results_df[results_df.model_type == 'LR']

print("Best Decision Tree")
print(find_best_model(dt_results, criteria='p_at_10'))
print("\n" + "Best K Nearest Neighbor")
print(find_best_model(knn_results, criteria='p_at_10'))
print("\n" + "Best Logistoic Regression")
print(find_best_model(lr_results, criteria='p_at_10'))
# Out:
# Best Decision Tree
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=100,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
#
# Best K Nearest Neighbor
# KNeighborsClassifier(algorithm='kd_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=-1, n_neighbors=100, p=2,
#            weights='distance')
#
# Best Logistoic Regression
# LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
best_clf = find_best_model(results_df, criteria='p_at_10')
best_clf
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=100,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %% [markdown]
# ### Rank the voters by their predicted propensity to vote

# %%
thresh, topN = 0.5, 5000

final,ids, cnt = [], [], 0
y_scores = best_clf.predict_proba(x_test)[:,1]
dfinal = x_test.copy()
dfinal['label_value'] = y_test
dfinal['scores'] = y_scores
dfinal['score'] = np.where(dfinal['scores'] > thresh, 1, 0)

dfinal = dfinal.sort_values(by='scores', ascending=False)
df_id = l[['idx']]
dF = pd.merge(df_id, dfinal, left_index=True, right_index=True)
dF = dF.sort_values(by='scores', ascending=False)
mini= dF[['idx', 'scores', 'score']]

top_lst = [tuple(x) for x in mini.values]

for idx, scores, score in top_lst:
    if idx not in ids and cnt <=topN-1:
        ids.append(idx)
        final.append(idx)
        cnt +=1

# %%
s = pd.DataFrame()
s['idx'] = final

# %%
demo = l[['idx', 'name', 'county', 'city', 'zip', 'address', 'phone', 'gender', 'age', 'white', 'black', 'hispanic', 'dem']]
demo = demo.drop_duplicates()

# %%
s = s.merge(demo, on=['idx'], how='left')

# %% [markdown]
# #### Remove Republicans to make sure you have 2000 potential democratic voters.

# %%
dem_potentials = s[s.dem == 1.0][:2000]
dem_potentials.shape
# Out:
# (2000, 13)

# %% [markdown]
# ### Make a list of the 1,000 people your door-to-door campaign should contact.

# %% [markdown]
# #### In order to minimize logistics issues, I decided to select the 1000 voters who lived in more similar areas for door to door contact. I counted how many people lived in each of the counties, and selected the 16 where the most likely voters lived.

# %%
county_size = dem_potentials.county.value_counts()
counties = []

n = 0
for idx, val in county_size.iteritems():
    if n < 1000:
        print(idx, val)
        n += val
        counties.append(idx)
# Out:
# BUNCOMBE 150
# NEW HANOVER 68
# JOHNSTON 67
# CUMBERLAND 66
# CRAVEN 60
# HARNETT 57
# ROCKINGHAM 55
# LENOIR 55
# SURRY 52
# HAYWOOD 49
# CABARRUS 48
# RUTHERFORD 46
# HENDERSON 46
# WILSON 46
# WAYNE 46
# BRUNSWICK 44
# SAMPSON 41
# CHATHAM 41

# %%
dem_potentials['gender'] = dem_potentials.gender.apply(lambda x: 'F' if x == 1 else 'M')

# %%
door = dem_potentials[dem_potentials.county.isin(counties)][:1000]
door.to_csv('PS4_door_to_door.csv')

# %% [markdown]
# ### Make another list of the 1,000 people you would like to reach via direct mail.

# %%
letters = dem_potentials[~dem_potentials.isin(door)].dropna()
letters.to_csv('PS4_by_direct_mail.csv')

# %% [markdown]
# ## Part 2: Produce Content

# %% [markdown]
# ### Describe how you would like to implement the door-to-door campaign: What is the message, who is the messenger etc.

# %% [markdown]
# #### This list is sorted by city so that volunteers from each city can focus on the people they need to target.

# %%
door.sort_values(by=['city', 'black'])
# Out:
#            idx                           name     county       city    zip  \
# 2101  AL207727       LUCY LORRAINE ROBERTSON    BUNCOMBE  ALEXANDER  28701
# 340   CJ113299              BETTY KING POOLE    JOHNSTON     ANGIER  27501
# 948    CA48278           PHYLLIS WOOD COZART     HARNETT     ANGIER  27501
# 1404   CA19263         RICHARD LEROY WELLS JR    HARNETT     ANGIER  27501
# 1681   CA91724          THERESA DEAN WILKINS     HARNETT     ANGIER  27501
# 3219   CJ84411            ETHEL ROSE JOHNSON    JOHNSTON     ANGIER  27501
# 3547   CA15102               BESSIE S PRUETT     HARNETT     ANGIER  27501
# 3743   CA19055           EIRA TAYLOR WATKINS     HARNETT     ANGIER  27501
# 4615   CA82506                PAMELA  TALLEY     HARNETT     ANGIER  27501
# 378    AX25605             LAURIER ROSS BUSH     CHATHAM       APEX  27523
# 672    AX19148         JESSE RAYMOND CARROLL     CHATHAM       APEX  27523
# 165    EB53451               JEROME  NEMZOFF       SURRY     ARARAT  27007
# 2767   EB47598          RICHARD ELGIN BRYANT       SURRY     ARARAT  27007
# 4384   EB21948     JEFFERSON COOPER DRAUGHON       SURRY     ARARAT  27007
# 353   AL142698             HILDEGARD  BUTLER    BUNCOMBE      ARDEN  28704
# 1239   BE36537          WALTER BULLOCK PARIS    BUNCOMBE      ARDEN  28704
# 2390  AL151743             PAUL JOSEPH TULEY    BUNCOMBE      ARDEN  28704
# 2735   AL79366               CHARLES J YODER    BUNCOMBE      ARDEN  28704
# 2947  AL155838              BRENDA KAY LEWIS    BUNCOMBE      ARDEN  28704
# 3026  AL118267              ALEC ANDREW FEHL    BUNCOMBE      ARDEN  28704
# 3286  AL216191          MARTHA CAROL LIVESAY    BUNCOMBE      ARDEN  28704
# 3348   CC47726          BRENDA PRAYTOR LEWIS   HENDERSON      ARDEN  28704
# 3576   AL94113          DAVID PIERCE BRADLEY    BUNCOMBE      ARDEN  28704
# 419    AK34972  GENEVIEVE  LETOURNEAU-HUGHES   BRUNSWICK        ASH  28420
# 161    AL11869        WADE GORRELL HAMPTON JR   BUNCOMBE  ASHEVILLE  28805
# 217     AL8889              JIM MARTEL EAKER    BUNCOMBE  ASHEVILLE  28804
# 278     AL6250              WILLIAM J CARTER    BUNCOMBE  ASHEVILLE  28804
# 344    AL24330            ALICE WILDE SLUDER    BUNCOMBE  ASHEVILLE  28806
# 588    AL12763          TONY ANTHONY HENSLEY    BUNCOMBE  ASHEVILLE  28806
# 602    AL30598       ROGER WILLIAM BISSINGER    BUNCOMBE  ASHEVILLE  28806
# ...        ...                            ...        ...        ...    ...
# 2348   EP74508      LUCILLE BLACKWELL GLOVER      WILSON     WILSON  27896
# 3020   EP23566            TIMOTHY ALLEN LAMM      WILSON     WILSON  27893
# 3343    EP7942            WANDA JO ETHERIDGE      WILSON     WILSON  27896
# 3554   EP23655      CLAYTON SCOVILL SAUNDERS      WILSON     WILSON  27893
# 3697   EP43158           PHYLLIS BAILEY WEBB      WILSON     WILSON  27893
# 3846   EP37148           SANDRA ALLEN RUFFIN      WILSON     WILSON  27896
# 3852   EP24400            JAMES WYATT O'NEAL      WILSON     WILSON  27896
# 4397   EP20676          JOSEPH KIMREY TURNER      WILSON     WILSON  27896
# 4450   EP65372         LINDA BARNES REBOLLAR      WILSON     WILSON  27896
# 118    EP16317          DAZELL BATTS PEARSON      WILSON     WILSON  27893
# 329    EP14455           MARY DEANS MCLAURIN      WILSON     WILSON  27893
# 1014   EP77661           MARY JANETTE MELTON      WILSON     WILSON  27893
# 1279   EP51915       CHRISTINE DELORIS DEANS      WILSON     WILSON  27893
# 2224   EP33673              RUTH ARTIS SMITH      WILSON     WILSON  27893
# 2263   EP21415            CAROLYN GRAY JONES      WILSON     WILSON  27893
# 2711   EP45007                   INEZ  MOORE      WILSON     WILSON  27893
# 2838   BX13342        PAMALA EDWARDS FRIESON      WILSON     WILSON  27896
# 2839   EP33960         ANTONIA MARIE COLLINS      WILSON     WILSON  27893
# 3539   EP19860        WILLIE RANDOLPH SUTTON      WILSON     WILSON  27896
# 3562   EP27980          DEBORAH GAIL SHERROD      WILSON     WILSON  27893
# 4023    EP8247               MARY RAY BARNES      WILSON     WILSON  27893
# 4040   EP35704             JANICE FAYE ALLEN      WILSON     WILSON  27893
# 4192   EP62059      LUCILLE VIRGINIA LIGGINS      WILSON     WILSON  27893
# 4210   EP35173          JAMES HEDERICK MILLS      WILSON     WILSON  27893
# 4329   EP83131                 LIONEL  LEWIS      WILSON     WILSON  27893
# 4616   EP41179                ROBERT J JONES      WILSON     WILSON  27893
# 358    AK85843          GAIL TRAISTER GIBSON   BRUNSWICK   WINNABOW  28479
# 2350   AK73402            PATSY RYALS PALLAS   BRUNSWICK   WINNABOW  28479
# 1827  CJ125695               RANDY LEE ONEAL    JOHNSTON    ZEBULON  27597
# 3396   CJ17082         JENNY PHILLIPS CREECH    JOHNSTON    ZEBULON  27597
#
#                             address         phone gender  age  white  black  \
# 2101                15  DONNA LN     828 484 9041      F   84    1.0    0.0
# 340     1625  MASSENGILL POND RD     919 639 6185      F   80    1.0    0.0
# 948          115  HONEYCUTT DR   #D  910 892 7040      F   62    1.0    0.0
# 1404               441  WELLS LN     919 639 4389      M   61    1.0    0.0
# 1681   2563  OAK GROVE CHURCH RD     919 639 4847      F   53    1.0    0.0
# 3219       105  PLEASANT PINE DR     919 331 8085      F   66    1.0    0.0
# 3547             9767  NC 210 N      919 639 2284      F   88    1.0    0.0
# 3743             372 N BROAD ST E    919 639 4588      F   88    1.0    0.0
# 4615              321  MANGUM RD     919 639 8167      F   49    1.0    0.0
# 378          107  SHADY LANE CIR     919 828 6260      M   71    1.0    0.0
# 672     2071  HOLLANDS CHAPEL RD     919 632 6394      M   75    1.0    0.0
# 165         103  SIMMONS FARM LN     336 374 7373      M   77    1.0    0.0
# 2767             3580  ARARAT RD     336 374 5345      M   70    1.0    0.0
# 4384  984  LITTLE MOUNTAIN CH RD     336 374 2092      M   62    1.0    0.0
# 353       300  LONG SHOALS RD   #4C  828 681 8134      F   80    1.0    0.0
# 1239               7  BRAMBLE CT     828 676 0059      M   68    1.0    0.0
# 2390             304  ROXBURY PL     828 684 4010      M   51    1.0    0.0
# 2735             7  TURNBERRY DR     828 253 8670      M   70    1.0    0.0
# 2947               48  LINDEN ST     828 681 9840      F   46    1.0    0.0
# 3026         40  RHODODENDRON DR     828 236 3836      M   45    1.0    0.0
# 3286          24  AVERY CREEK RD     828 687 9866      F   60    1.0    0.0
# 3348          0  BAGWELL MILL RD     828 684 8870      F   59    1.0    0.0
# 3576        45  MOUNTAIN VIEW DR     828 687 4468      M   57    1.0    0.0
# 419      7027  HUGHES-SMITH RD NW    910 287 3757      F   79    1.0    0.0
# 161               22  CHATEAU PL     828 254 4202      M   83    1.0    0.0
# 217        8 E BAIRD MOUNTAIN RD     828 645 7066      M   76    1.0    0.0
# 278            141  MACEDONIA RD     828 253 2002      M   80    1.0    0.0
# 344       731  NEW LEICESTER HWY     828 258 1373      F   80    1.0    0.0
# 588             39  DELAWARE AVE     828 254 4250      M   79    1.0    0.0
# 602           30  FIELDCREST CIR     828 255 8606      M   79    1.0    0.0
# ...                             ...           ...    ...  ...    ...    ...
# 2348      5655  HORNES CHURCH RD     252 243 6513      F   51    1.0    0.0
# 3020               1802  LYNN DR     252 246 9774      M   45    1.0    0.0
# 3343           1111  TREEMONT RD     252 399 7986      F   55    1.0    0.0
# 3554                505  PIKE ST     252 237 6311      M   89    1.0    0.0
# 3697        4313  TARTTS MILL RD     252 237 3138      F   64    1.0    0.0
# 3846  3303  CHRISTOPHER DR   #APT-A  252 281 5397      F   61    1.0    0.0
# 3852          1116  WINDEMERE DR     252 291 8204      M   59    1.0    0.0
# 4397             1221  BUXTON RD     252 237 7478      M   62    1.0    0.0
# 4450        4314  CAM STRADER DR     252 237 0237      F   54    1.0    0.0
# 118               1305  QUEEN ST     252 243 5501      F   79    0.0    1.0
# 329                414  VICK ST E    252 237 6009      F   87    0.0    1.0
# 1014        5541  SCUPPERNONG RD     252 307 0016      F   64    0.0    1.0
# 1279            223  SPRUCE ST SW    252 243 0381      F   68    0.0    1.0
# 2224               804  VIOLA ST     252 243 3759      F   76    0.0    1.0
# 2263           205  FAIRVIEW AVE     252 291 6582      F   59    0.0    1.0
# 2711             119  GARNER ST W    252 399 0434      F   67    0.0    1.0
# 2838         1704  LAKESIDE DR NW    252 206 6610      F   41    0.0    1.0
# 2839          1118  CRAWFORD ST S    252 237 5633      F   41    0.0    1.0
# 3539             2612  WILLIS CT     252 243 0808      M   59    0.0    1.0
# 3562           5708  WOODSIDE RD     252 236 4576      F   58    0.0    1.0
# 4023         2124  SILVERLEAF RD     252 237 1280      F   60    0.0    1.0
# 4040             504  DEWEY ST SW    252 243 5403      F   60    0.0    1.0
# 4192             1815  NASH ST NW    252 246 0429      F   65    0.0    1.0
# 4210              911  MEADOW ST     252 399 7639      M   60    0.0    1.0
# 4329          1707  WESTWOOD AVE     252 230 3729      M   61    0.0    1.0
# 4616      211  KENAN ST W  #APT-128  252 243 9858      M   69    0.0    1.0
# 358            735  BEACHWALK DR     910 371 1460      F   72    1.0    0.0
# 2350       1405  CHERRYTREE RD NE    910 253 0034      F   51    1.0    0.0
# 1827           661  OLD EASON RD     919 815 6806      M   58    1.0    0.0
# 3396            13071  NC 39 HWY     919 269 6315      F   59    1.0    0.0
#
#       hispanic  dem
# 2101       0.0  1.0
# 340        0.0  1.0
# 948        0.0  1.0
# 1404       0.0  1.0
# 1681       0.0  1.0
# 3219       0.0  1.0
# 3547       0.0  1.0
# 3743       0.0  1.0
# 4615       0.0  1.0
# 378        0.0  1.0
# 672        0.0  1.0
# 165        0.0  1.0
# 2767       0.0  1.0
# 4384       0.0  1.0
# 353        0.0  1.0
# 1239       0.0  1.0
# 2390       0.0  1.0
# 2735       0.0  1.0
# 2947       0.0  1.0
# 3026       0.0  1.0
# 3286       0.0  1.0
# 3348       0.0  1.0
# 3576       0.0  1.0
# 419        0.0  1.0
# 161        0.0  1.0
# 217        0.0  1.0
# 278        0.0  1.0
# 344        0.0  1.0
# 588        0.0  1.0
# 602        0.0  1.0
# ...        ...  ...
# 2348       0.0  1.0
# 3020       0.0  1.0
# 3343       0.0  1.0
# 3554       0.0  1.0
# 3697       0.0  1.0
# 3846       0.0  1.0
# 3852       0.0  1.0
# 4397       0.0  1.0
# 4450       0.0  1.0
# 118        0.0  1.0
# 329        0.0  1.0
# 1014       0.0  1.0
# 1279       0.0  1.0
# 2224       0.0  1.0
# 2263       0.0  1.0
# 2711       0.0  1.0
# 2838       0.0  1.0
# 2839       0.0  1.0
# 3539       0.0  1.0
# 3562       0.0  1.0
# 4023       0.0  1.0
# 4040       0.0  1.0
# 4192       0.0  1.0
# 4210       0.0  1.0
# 4329       0.0  1.0
# 4616       0.0  1.0
# 358        0.0  1.0
# 2350       0.0  1.0
# 1827       0.0  1.0
# 3396       0.0  1.0
#
# [1000 rows x 13 columns]

# %%
door.gender.value_counts()
# Out:
# F    625
# M    375
# Name: gender, dtype: int64

# %%
door.age.describe()
# Out:
# count    1000.000000
# mean       66.056000
# std        11.689633
# min        36.000000
# 25%        58.000000
# 50%        65.000000
# 75%        74.000000
# max       103.000000
# Name: age, dtype: float64

# %%
"white", door.white.mean(), "black", door.black.mean(), "hispanic", door.hispanic.mean(),
# Out:
# ('white', 0.815, 'black', 0.174, 'hispanic', 0.003)

# %%
door[(door.white == 1) & (door.gender == 'F')].shape
# Out:
# (501, 13)

# %%
black_door = door[door.black == 1]
black_door.city.value_counts()[:5]
# Out:
# FAYETTEVILLE    20
# WILSON          17
# KINSTON         15
# REIDSVILLE      11
# GOLDSBORO       10
# Name: city, dtype: int64

# %%
black_door.gender.value_counts()
# Out:
# F    117
# M     57
# Name: gender, dtype: int64

# %% [markdown]
# ### Describe how you would like to implement the direct mail campaign: Write the letter you would like to be distributed.

# %%
"white", letters.white.mean(), "black", letters.black.mean(), "hispanic", letters.hispanic.mean(),
# Out:
# ('white', 0.764, 'black', 0.217, 'hispanic', 0.002)

# %%
letters.gender.value_counts()
# Out:
# F    628
# M    372
# Name: gender, dtype: int64

# %%
letters[letters.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [idx, name, county, city, zip, address, phone, gender, age, white, black, hispanic, dem]
# Index: []

# %%
letters.iloc[0]
# Out:
# idx                     CZ10393
# name           ROBERT T VEASEY
# county                    MOORE
# city                   ABERDEEN
# zip                       28315
# address     110  CAMPBELL ST
# phone              910 944 1666
# gender                        M
# age                          91
# white                         1
# black                         0
# hispanic                      0
# dem                           1
# Name: 23, dtype: object

# %%
l[l.name == 'LEE E HINTON ']
# Out:
#         county           name        city    zip           address  \
# 1170  JOHNSTON  LEE E HINTON   SMITHFIELD  27577  410 E HOLT ST
# 1170  JOHNSTON  LEE E HINTON   SMITHFIELD  27577  410 E HOLT ST
# 1170  JOHNSTON  LEE E HINTON   SMITHFIELD  27577  410 E HOLT ST
# 1170  JOHNSTON  LEE E HINTON   SMITHFIELD  27577  410 E HOLT ST
#
#              phone  gender  age precinct  cong_dist     ...      nc_house  \
# 1170  919 934 7925       0   46   PR26          7.0     ...          28.0
# 1170  919 934 7925       0   46   PR26          7.0     ...          28.0
# 1170  919 934 7925       0   46   PR26          7.0     ...          28.0
# 1170  919 934 7925       0   46   PR26          7.0     ...          28.0
#
#           idx white  black  hispanic  dem  rep  election_year voted  \
# 1170  CJ90250   0.0    1.0       0.0  1.0  0.0           2004   1.0
# 1170  CJ90250   0.0    1.0       0.0  1.0  0.0           2006   0.0
# 1170  CJ90250   0.0    1.0       0.0  1.0  0.0           2008   0.0
# 1170  CJ90250   0.0    1.0       0.0  1.0  0.0           2010   0.0
#
#       is_midterm
# 1170           1
# 1170           1
# 1170           1
# 1170           1
#
# [4 rows x 21 columns]
